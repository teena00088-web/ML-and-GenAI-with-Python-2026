# %% [markdown]
# ## Q1. Loan Approval Prediction
#
# ### Is this a classification or regression problem?
#
# This is a classification problem because the output belongs to one of two categories: Approved or Rejected.
#
# ### Which algorithm is most suitable?
#
# Decision Tree is the most suitable algorithm because it works well for classification tasks and provides easy-to-understand decision rules.

# %% [markdown]
# ## Q2. Feature vs Label
#
# A feature is an input variable used to make predictions, while a label is the output that the model predicts.
#
# Example:
# For house price prediction:
#
# Features:
# - House Size
# - Number of Bedrooms
# - Location
#
# Label:
# - House Price

# %% [markdown]
# ## Q3.
#
# A Decision Tree predicts that a customer will purchase a product.
#
# Explain how the model reaches this prediction.
#
# ### Answer
#
# A Decision Tree makes predictions by asking a sequence of questions about the input data.
#
# For example:
#
# 1. Is the customer's age greater than 30?
# 2. Is the customer's income greater than ₹50,000?
# 3. Based on the answers, the model reaches a final decision.
#
# The prediction is made when the model reaches a leaf node of the tree.

# %% [markdown]
# ## Q4.
#
# Why is KNN considered a supervised learning algorithm?
#
# Can KNN perform classification if labels are not available?
#
# ### Answer
#
# KNN is considered a supervised learning algorithm because it learns from labeled training data.
#
# Each training example has a known output or class label.
#
# No, KNN cannot perform classification if labels are not available because it relies on labeled neighbors to make predictions.

# %% [markdown]
# ## Q5.
#
# Suppose a KNN model uses:
#
# K = 5
#
# Nearest Neighbors:
# - Yes
# - Yes
# - No
# - Yes
# - No
#
# What will be the prediction and why?
#
# ### Answer
#
# Count:
#
# - Yes = 3
# - No = 2
#
# Prediction: Yes
#
# Reason:
#
# KNN uses majority voting. Since "Yes" appears more frequently than "No", the predicted class is Yes.

# %% [markdown]
# ## Q6.
#
# Explain the equation of Linear Regression:
#
# y = mx + b
#
# What do x, y, m, and b represent?
#
# ### Answer
#
# Where:
#
# - x = Independent Variable (Input)
# - y = Dependent Variable (Output)
# - m = Slope of the Line
# - b = Intercept
#
# Example:
#
# Salary = 5000 × Experience + 20000
#
# Here:
# - x = Experience
# - y = Salary
# - m = 5000
# - b = 20000

# %% [markdown]
# ## Q7.
#
# What is correlation?
#
# What does each of the following values indicate?
#
# +1, 0, -1
#
# ### Answer
#
# Correlation measures the strength and direction of the relationship between two variables.
#
# +1 : Perfect Positive Correlation. When one variable increases, the other also increases.
#
# 0 : No Correlation. There is no relationship between the variables.
#
# -1 : Perfect Negative Correlation. When one variable increases, the other decreases.

# %% [markdown]
# ## Q8.
#
# A disease detection model produced the following result:
#
# Actual Condition: Disease Present
#
# Prediction: Healthy
#
# What type of prediction is this?
#
# Why can this be dangerous?
#
# ### Answer
#
# This is a False Negative (FN).
#
# It is dangerous because the patient actually has the disease but is predicted as healthy. This may delay treatment, worsen the disease, and increase health risks.

# %% [markdown]
# ## Q9.
#
# What is the purpose of a Confusion Matrix?
#
# How is it different from a Correlation Matrix?
#
# ### Answer
#
# A Confusion Matrix is used to evaluate the performance of a classification model.
#
# It shows:
# - True Positives (TP)
# - True Negatives (TN)
# - False Positives (FP)
# - False Negatives (FN)
#
# Difference:
#
# Confusion Matrix:
# - Evaluates classification models.
# - Uses actual and predicted values.
#
# Correlation Matrix:
# - Measures relationships between variables.
# - Uses correlation coefficients.

# %% [markdown]
# ## Q10.
#
# Compare the following algorithms in one or two lines each:
#
# ### Decision Tree
# A Decision Tree makes predictions using a series of decision rules arranged in a tree structure.
#
# ### KNN
# KNN predicts a class based on the majority class of the nearest data points.
#
# ### SVM
# SVM finds the best boundary that separates different classes of data.
#
# ### Linear Regression
# Linear Regression predicts continuous numerical values by fitting a straight line to the data.
#
# ### Neural Network
# A Neural Network learns complex patterns from data using multiple interconnected layers inspired by the human brain.
